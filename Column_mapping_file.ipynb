# %% [markdown]
# Customer Vendor Mapping

# %%
import pandas as pd
import numpy as np
from sentence_transformers import SentenceTransformer
from scipy.spatial.distance import cdist
import xgboost as xgb

# %%
customer_file = "/content/customer_standard_format.csv"
vendor_file = "/content/vendor_input_format.csv"

# %%
import pandas as pd
import numpy as np
from sentence_transformers import SentenceTransformer
from scipy.spatial.distance import cdist
import xgboost as xgb

def load_data(customer_file, vendor_file):
    customer_df = pd.read_csv(customer_file, encoding="ISO-8859-1")
    vendor_df = pd.read_csv(vendor_file, encoding="ISO-8859-1")
    return customer_df, vendor_df

def preprocess_data(customer_df, vendor_df):
    customer_df = customer_df.fillna('').copy()
    vendor_df = vendor_df.fillna('').copy()

    customer_df['Business Definition'] = customer_df['Business Definition'].str.lower().str.strip()
    vendor_df['Business Name'] = vendor_df['Business Name'].str.lower().str.strip()

    customer_df['combined_text'] = customer_df['Business Definition']
    vendor_df['combined_text'] = vendor_df['Business Name']

    return customer_df, vendor_df

def generate_embeddings(customer_texts, vendor_texts, model_name='all-MiniLM-L6-v2'):
    model = SentenceTransformer(model_name)
    customer_embeddings = model.encode(customer_texts, convert_to_numpy=True)
    vendor_embeddings = model.encode(vendor_texts, convert_to_numpy=True)
    return customer_embeddings, vendor_embeddings

def extract_features(customer_df, vendor_df, customer_embeddings, vendor_embeddings):
    features = []
    labels = []
    similarity_matrix = 1 - cdist(vendor_embeddings, customer_embeddings, metric='cosine')

    for i, vendor_row in vendor_df.iterrows():
        for j, customer_row in customer_df.iterrows():
            similarity_score = similarity_matrix[i, j]
            features.append([similarity_score, len(vendor_row['combined_text']), len(customer_row['combined_text'])])
            labels.append(1 if similarity_score >= 0.5 else 0)

    return np.array(features), np.array(labels), similarity_matrix

def train_xgboost_model(X_train, y_train):
    model = xgb.XGBClassifier(objective='binary:logistic', n_estimators=100, use_label_encoder=False, eval_metric='logloss')
    model.fit(X_train, y_train)
    return model

def compute_contextual_mappings(customer_df, vendor_df, customer_embeddings, vendor_embeddings, similarity_threshold=0.5):
    X_train, y_train, similarity_matrix = extract_features(customer_df, vendor_df, customer_embeddings, vendor_embeddings)
    model = train_xgboost_model(X_train, y_train)

    mapping_data = []

    for i, vendor_row in vendor_df.iterrows():
        best_match = None
        best_score = 0

        for j, customer_row in customer_df.iterrows():
            similarity_score = similarity_matrix[i, j]
            features = np.array([[similarity_score, len(vendor_row['combined_text']), len(customer_row['combined_text'])]])
            prediction = model.predict_proba(features)[0, 1]  # Get probability score

            if prediction > best_score:
                best_score = prediction
                best_match = j

        mapping_entry = {
            **vendor_row.to_dict(),
            'Mapped Customer Field': customer_df.iloc[best_match]['Field Name'] if best_match is not None else None,
            'Mapped Customer Business Definition': customer_df.iloc[best_match]['Business Definition'] if best_match is not None else None,
            'Prediction Score': best_score
        }
        mapping_data.append(mapping_entry)

    return pd.DataFrame(mapping_data)

def automate_customer_mapping(customer_file, vendor_file, output_file='automated_mapped_fields.csv', similarity_threshold=0.5):
    customer_df, vendor_df = load_data(customer_file, vendor_file)
    customer_df, vendor_df = preprocess_data(customer_df, vendor_df)

    customer_embeddings, vendor_embeddings = generate_embeddings(
        customer_df['combined_text'].tolist(),
        vendor_df['combined_text'].tolist()
    )

    mapping_df = compute_contextual_mappings(
        customer_df, vendor_df, customer_embeddings, vendor_embeddings,
        similarity_threshold=similarity_threshold
    )

    mapping_df.to_csv(output_file, index=False)
    print(f"Mapping complete. Results saved as '{output_file}'")
    return mapping_df

# %%
customer_file_path = "/content/customer_standard_format.csv"
vendor_file_path = "/content/vendor_input_format.csv"

mapped_results = automate_customer_mapping(customer_file_path, vendor_file_path, similarity_threshold=0.6)
# Out:
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [08:14:43] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Mapping complete. Results saved as 'automated_mapped_fields.csv'

# %%
mapped_results
# Out:
#                   Field Name             Business Name Usage Data Type  Min  \
# 0                  Record ID                 record id     R      CHAR    3
# 1              Record Number             record number     R       INT    1
# 2                   Claim ID                  claim id     R   VARCHAR    1
# 3             Original_Claim            original_claim     O   VARCHAR    1
# 4                   Group_ID                  group_id     R   VARCHAR    1
# 5                        PCN                       pcn     O   VARCHAR    1
# 6                Employee_ID               employee_id     O   VARCHAR    1
# 7                        SSN                       ssn     R      CHAR    9
# 8                 Patient_ID                patient_id     R   VARCHAR    1
# 9          Patient_Last_Name         patient_last_name     R   VARCHAR    1
# 10        Patient_First_Name        patient_first_name     R   VARCHAR    1
# 11         Patient_Address 1         patient_address 1     O   VARCHAR    1
# 12         Patient_Address 2         patient_address 2     O   VARCHAR    1
# 13              Patient_City              patient_city     O   VARCHAR    1
# 14             Patient_State             patient_state     O   VARCHAR    1
# 15          Patient_Zip_code          patient_zip_code     O   VARCHAR    1
# 16              Relationship              relationship     R       INT    0
# 17             Date_of_Birth             date_of_birth     R      DATE    8
# 18           Prescriber_Name           prescriber_name     O   VARCHAR    1
# 19             Pharmacy_Name             pharmacy_name     R   VARCHAR    1
# 20             Pharmacy_Type             pharmacy_type     O      CHAR    1
# 21           Date_of_Service           date_of_service     R      DATE    8
# 22           Prescription_No           prescription_no     O   VARCHAR    1
# 23  Date_Prescription_Filled  date_prescription_filled     R      DATE    8
# 24            In-Out_Network            in-out_network     O      CHAR    1
# 25                       NDC                       ndc     R   VARCHAR    1
# 26                Label_Name                label_name     R   VARCHAR    1
# 27             Brand_Generic             brand_generic     R      CHAR    1
# 28             Drug_Strength             drug_strength     R   VARCHAR    1
# 29               Days_Supply               days_supply     R       INT    0
# 30                  Quantity                  quantity     R       INT    0
# 31               Dosage Form               dosage form     0   VARCHAR    1
# 32                 Formulary                 formulary     R   VARCHAR    1
# 33       Total_Billed_Amount       total_billed_amount     R   DECIMAL    0
# 34          Plan_Paid_Amount          plan_paid_amount     R   DECIMAL    0
# 35        Member_Copay_Coins        member_copay_coins     R   DECIMAL    0
# 36         Member_Deductible         member_deductible     R   DECIMAL    0
# 37         Member_Other_Cost         member_other_cost     R   DECIMAL    0
# 38  Member_Total_Paid_Amount  member_total_paid_amount     R   DECIMAL    0
# 39                 Paid_Date                 paid_date     R      DATE    8
# 40                    Status                    status     O      CHAR    1
#
#     Max Valid Values             combined_text Mapped Customer Field  \
# 0     3          CLM                 record id              RECORDID
# 1    10                          record number              RECORDID
# 2    50                               claim id               GROUPID
# 3    50                         original_claim               PAMCCDE
# 4    50                               group_id              CLTPTPST
# 5    10                                    pcn              CLTPTPST
# 6    50                            employee_id              CLTPTPST
# 7     9                                    ssn              CLTPTPST
# 8    30                             patient_id            CARDHOLDER
# 9    50                      patient_last_name            PPRSLSTNME
# 10   35                     patient_first_name            PPRSFSTNME
# 11   35                      patient_address 1            PPRSFSTNME
# 12   35                      patient_address 2            PLNPNDCLST
# 13   30                           patient_city            CAREFACNAM
# 14    2                          patient_state            CAREFACNAM
# 15    5                       patient_zip_code              PHARMZIP
# 16    0        1,2,3              relationship              CLTPTPST
# 17    8                          date_of_birth              MBRBIRTH
# 18   50                        prescriber_name                ABAQTX
# 19   50                          pharmacy_name            PRVNCPDPID
# 20    1      R,M,H,C             pharmacy_type            PRVNCPDPID
# 21    8                        date_of_service             GROUPPLAN
# 22   50                        prescription_no                AOB9TX
# 23    8               date_prescription_filled            OTHRPHARM1
# 24    1                         in-out_network            GENERICNME
# 25   50                                    ndc              CLTPTPST
# 26   50                             label_name              CLTPTPST
# 27    1                          brand_generic            GENERICNME
# 28   20                          drug_strength            METRICSTRG
# 29    0                            days_supply              CLTPTPST
# 30    0                               quantity            DRGSTRGUOM
# 31   20                            dosage form            METRICSTRG
# 32    1                              formulary                FORMID
# 33    0                    total_billed_amount              CLTPTPST
# 34    0                       plan_paid_amount            INDLBFTREM
# 35    0                     member_copay_coins            PLNPNDCLST
# 36    0                      member_deductible            CCTRESRV12
# 37    0                      member_other_cost          CCTRESERV3.3
# 38    0               member_total_paid_amount              CLTPTPST
# 39    8                              paid_date              CLTPTPST
# 40    1                                 status              CLTPTPST
#
#                   Mapped Customer Business Definition  Prediction Score
# 0   the number assigned to the record for identifi...          0.994999
# 1   the number assigned to the record for identifi...          0.994309
# 2   the identifier assigned to the third level of ...          0.999447
# 3   the type of prior authorization associated wit...          0.992340
# 4   the code that identifies the final member pay ...          0.000160
# 5   the code that identifies the final member pay ...          0.000160
# 6   the code that identifies the final member pay ...          0.000089
# 7   the code that identifies the final member pay ...          0.000160
# 8   the identification number assigned to the pers...          0.825512
# 9   the last name of the member's primary medical ...          0.310133
# 10  the first name of the member's primary medical...          0.994109
# 11  the first name of the member's primary medical...          0.310133
# 12  the benefit plan's list of preferred drugs, gr...          0.000114
# 13  the name of the healthcare facility that is as...          0.982415
# 14  the name of the healthcare facility that is as...          0.991789
# 15  the pharmacy's zip code.\nvalue is derived fro...          0.998697
# 16  the code that identifies the final member pay ...          0.000077
# 17  the date of birth of the member based on the e...          0.997434
# 18  the subscriber's last name based on the eligib...          0.992300
# 19  a unique 7-digit number assigned by the nation...          0.999216
# 20  a unique 7-digit number assigned by the nation...          0.999216
# 21  the benefit plan identifier associated to the ...          0.000168
# 22  the street address (line 1) of the pharmacy th...          0.998522
# 23  the code that indicates the location where the...          0.998617
# 24  the name of the generic drug, which is commonl...          0.000102
# 25  the code that identifies the final member pay ...          0.000160
# 26  the code that identifies the final member pay ...          0.000094
# 27  the name of the generic drug, which is commonl...          0.999175
# 28  the strength or amount of medicine in a dispen...          0.997353
# 29  the code that identifies the final member pay ...          0.000089
# 30  the unit of measure for the dose / strength of...          0.661214
# 31  the strength or amount of medicine in a dispen...          0.996995
# 32  the formulary id against which the claim proce...          0.994688
# 33  the code that identifies the final member pay ...          0.999194
# 34  the dollar amount that the benefit plan has le...          0.997048
# 35  the benefit plan's list of preferred drugs, gr...          0.000128
# 36  the indifividual deductible amount applied on ...          0.997379
# 37  the cost share code read from the preferred li...          0.991432
# 38  the code that identifies the final member pay ...          0.999026
# 39  the code that identifies the final member pay ...          0.000126
# 40  the code that identifies the final member pay ...          0.000160
